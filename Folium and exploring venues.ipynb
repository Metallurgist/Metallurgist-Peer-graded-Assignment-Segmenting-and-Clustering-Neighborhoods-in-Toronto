# %% [markdown]
# # Exploring the venues / locations / events with respect to a landmark

# %%
# %config IPCompleter.greedy=True

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ALFKCZOUD5L4R1BBEVEVJT3G2FWIPRHJX0AMMJT2DSI3GPPS' # your Foursquare ID
CLIENT_SECRET = 'VKFBW4PSYNDTRLXMSLI3I44L4JF3ETZGAWET3I0FLTG1KOTF' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ALFKCZOUD5L4R1BBEVEVJT3G2FWIPRHJX0AMMJT2DSI3GPPS
# CLIENT_SECRET:VKFBW4PSYNDTRLXMSLI3I44L4JF3ETZGAWET3I0FLTG1KOTF

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7151482 -74.0156573

# %%
# University of Toronto - St. George Campus
# Web address --> 27 King's College Cir, Toronto, ON M5S, Canada

address = '27 Kings College Cir, Toronto'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6607225 -79.3958255

# %% [markdown]
# <hr><hr><b>Exploring the Banks around Anna University<b>

# %%
address = 'Anna University,Chennai, India'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 13.0083174 80.2334438

# %%
search_query = 'Bank'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Bank .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ALFKCZOUD5L4R1BBEVEVJT3G2FWIPRHJX0AMMJT2DSI3GPPS&client_secret=VKFBW4PSYNDTRLXMSLI3I44L4JF3ETZGAWET3I0FLTG1KOTF&ll=13.0083174,80.2334438&v=20180604&query=Bank&radius=1000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eca5912f7706a001bb0077b'},
#  'response': {'venues': [{'id': '4d511a7adcce224b465dde1b',
#     'name': 'State Bank of India',
#     'location': {'address': 'Anna University, Guindy',
#      'lat': 13.01104922618117,
#      'lng': 80.23656149309292,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.01104922618117,
#        'lng': 80.23656149309292}],
#      'distance': 454,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University, Guindy',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590319358',
#     'hasPerk': False},
#    {'id': '50584138e4b018d4b8c30473',
#     'name': 'State Bank of India',
#     'location': {'address': 'Sri Nagar Colony',
#      'crossStreet': 'Little Mount',
#      'lat': 13.012181623939181,
#      'lng': 80.22749944186089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.012181623939181,
#        'lng': 80.22749944186089}],
#      'distance': 775,
#      'postalCode': '600015',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Sri Nagar Colony (Little Mount)',
#       'Chennai 600015',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590319358',
#     'hasPerk': False},
#    {'id': '4cd10c0c48b837042e78f6de',
#     'name': 'Indian Overseas Bank',
#     'location': {'crossStreet': 'Srinagar Colony',
#      'lat': 13.013068692387705,
#      'lng': 80.22867037422735,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.013068692387705,
#        'lng': 80.22867037422735}],
#      'distance': 740,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Chennai', 'Tamil Nadu', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590319358',
#     'hasPerk': False},
#    {'id': '4ff15b7ee4b0b61f2ad89cfb',
#     'name': 'SBI Bank',
#     'location': {'address': 'Anna University',
#      'lat': 13.012176231033509,
#      'lng': 80.24031891116303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.012176231033509,
#        'lng': 80.24031891116303}],
#      'distance': 860,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590319358',
#     'hasPerk': False},
#    {'id': '5c2a84c09cadd9002bf65758',
#     'name': 'Axis Bank ATM',
#     'location': {'address': 'No 24',
#      'crossStreet': 'Venkatapuram',
#      'lat': 13.01242,
#      'lng': 80.22553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.01242,
#        'lng': 80.22553}],
#      'distance': 972,
#      'postalCode': '600053',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['No 24 (Venkatapuram)',
#       'Chennai 600053',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b56',
#       'name': 'ATM',
#       'pluralName': 'ATMs',
#       'shortName': 'ATM',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590319358',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                  name  \
# 0  4d511a7adcce224b465dde1b   State Bank of India
# 1  50584138e4b018d4b8c30473   State Bank of India
# 2  4cd10c0c48b837042e78f6de  Indian Overseas Bank
# 3  4ff15b7ee4b0b61f2ad89cfb              SBI Bank
# 4  5c2a84c09cadd9002bf65758         Axis Bank ATM
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d197941735', 'name': 'C...  v-1590319358    False
# 1  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1590319358    False
# 2  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1590319358    False
# 3  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...  v-1590319358    False
# 4  [{'id': '52f2ab2ebcbc57f1066b8b56', 'name': 'A...  v-1590319358    False
#
#           location.address  location.lat  location.lng  \
# 0  Anna University, Guindy     13.011049     80.236561
# 1         Sri Nagar Colony     13.012182     80.227499
# 2                      NaN     13.013069     80.228670
# 3          Anna University     13.012176     80.240319
# 4                    No 24     13.012420     80.225530
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 13.01104922618117...                454
# 1  [{'label': 'display', 'lat': 13.01218162393918...                775
# 2  [{'label': 'display', 'lat': 13.01306869238770...                740
# 3  [{'label': 'display', 'lat': 13.01217623103350...                860
# 4  [{'label': 'display', 'lat': 13.01242, 'lng': ...                972
#
#   location.cc location.city location.state location.country  \
# 0          IN       Chennai     Tamil Nadu            India
# 1          IN       Chennai     Tamil Nadu            India
# 2          IN       Chennai     Tamil Nadu            India
# 3          IN       Chennai     Tamil Nadu            India
# 4          IN       Chennai     Tamil Nadu            India
#
#                            location.formattedAddress location.crossStreet  \
# 0  [Anna University, Guindy, Chennai, Tamil Nadu,...                  NaN
# 1  [Sri Nagar Colony (Little Mount), Chennai 6000...         Little Mount
# 2                       [Chennai, Tamil Nadu, India]      Srinagar Colony
# 3      [Anna University, Chennai, Tamil Nadu, India]                  NaN
# 4  [No 24 (Venkatapuram), Chennai 600053, Tamil N...         Venkatapuram
#
#   location.postalCode
# 0                 NaN
# 1              600015
# 2                 NaN
# 3                 NaN
# 4              600053

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                    name                       categories  \
# 0   State Bank of India  College Administrative Building
# 1   State Bank of India                             Bank
# 2  Indian Overseas Bank                             Bank
# 3              SBI Bank                             Bank
# 4         Axis Bank ATM                              ATM
#
#                    address        lat        lng  \
# 0  Anna University, Guindy  13.011049  80.236561
# 1         Sri Nagar Colony  13.012182  80.227499
# 2                      NaN  13.013069  80.228670
# 3          Anna University  13.012176  80.240319
# 4                    No 24  13.012420  80.225530
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 13.01104922618117...       454  IN  Chennai
# 1  [{'label': 'display', 'lat': 13.01218162393918...       775  IN  Chennai
# 2  [{'label': 'display', 'lat': 13.01306869238770...       740  IN  Chennai
# 3  [{'label': 'display', 'lat': 13.01217623103350...       860  IN  Chennai
# 4  [{'label': 'display', 'lat': 13.01242, 'lng': ...       972  IN  Chennai
#
#         state country                                   formattedAddress  \
# 0  Tamil Nadu   India  [Anna University, Guindy, Chennai, Tamil Nadu,...
# 1  Tamil Nadu   India  [Sri Nagar Colony (Little Mount), Chennai 6000...
# 2  Tamil Nadu   India                       [Chennai, Tamil Nadu, India]
# 3  Tamil Nadu   India      [Anna University, Chennai, Tamil Nadu, India]
# 4  Tamil Nadu   India  [No 24 (Venkatapuram), Chennai 600053, Tamil N...
#
#        crossStreet postalCode                        id
# 0              NaN        NaN  4d511a7adcce224b465dde1b
# 1     Little Mount     600015  50584138e4b018d4b8c30473
# 2  Srinagar Colony        NaN  4cd10c0c48b837042e78f6de
# 3              NaN        NaN  4ff15b7ee4b0b61f2ad89cfb
# 4     Venkatapuram     600053  5c2a84c09cadd9002bf65758

# %%
dataframe_filtered.name
# Out:
# 0     State Bank of India
# 1     State Bank of India
# 2    Indian Overseas Bank
# 3                SBI Bank
# 4           Axis Bank ATM
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Anna University',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <hr><hr>

# %%
search_query_park = 'park'
radius = 1000
print(search_query_park + ' .... OK!')
# Out:
# park .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query_park, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ALFKCZOUD5L4R1BBEVEVJT3G2FWIPRHJX0AMMJT2DSI3GPPS&client_secret=VKFBW4PSYNDTRLXMSLI3I44L4JF3ETZGAWET3I0FLTG1KOTF&ll=13.0083174,80.2334438&v=20180604&query=park&radius=1000&limit=30'

# %%
results_park = requests.get(url).json()
results_park
# Out:
# {'meta': {'code': 200, 'requestId': '5eca5c06949393001c5edbcc'},
#  'response': {'venues': [{'id': '4bc77dc293bdeee1b47037ae',
#     'name': 'The Park Hotel Chennai',
#     'location': {'address': '601 Anna Salai',
#      'lat': 13.00748881578164,
#      'lng': 80.23680110152569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.00748881578164,
#        'lng': 80.23680110152569}],
#      'distance': 375,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['601 Anna Salai', 'Chennai', 'Tamil Nadu', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4b9cbd6cf964a520267936e3',
#     'name': 'guindy childrens park',
#     'location': {'address': 'sardar patel rd',
#      'lat': 13.005268593518764,
#      'lng': 80.2366304397583,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.005268593518764,
#        'lng': 80.2366304397583}],
#      'distance': 484,
#      'postalCode': '600032',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['sardar patel rd',
#       'Chennai 600032',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4feedb1be4b01127cbc19930',
#     'name': 'Guindy National Park',
#     'location': {'address': 'Sardar Patel Rd',
#      'crossStreet': 'Sardar Patel Road',
#      'lat': 13.006087724011142,
#      'lng': 80.2388595279453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.006087724011142,
#        'lng': 80.2388595279453}],
#      'distance': 637,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Sardar Patel Rd (Sardar Patel Road)',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4f07eb2fe4b0fcefa80570d4',
#     'name': 'Childrens & snake park',
#     'location': {'lat': 13.00675322951637,
#      'lng': 80.2385001237523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.00675322951637,
#        'lng': 80.2385001237523}],
#      'distance': 575,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4c26dfd3c11dc9b672d62924',
#     'name': "Children's Park, Guindy",
#     'location': {'lat': 13.004399918951982,
#      'lng': 80.23848378716193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.004399918951982,
#        'lng': 80.23848378716193}],
#      'distance': 699,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '5bae9231bedf3950379f89d0',
#       'name': 'State / Provincial Park',
#       'pluralName': 'State / Provincial Parks',
#       'shortName': 'State / Provincial Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4f3373b7e4b00f87aa73f865',
#     'name': 'Herbal Park',
#     'location': {'address': 'Herbal Park',
#      'crossStreet': 'Madras University',
#      'lat': 13.008699644264727,
#      'lng': 80.23912635734732,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.008699644264727,
#        'lng': 80.23912635734732}],
#      'distance': 617,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Herbal Park (Madras University)',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4c550f46f5f3d13a152e20fb',
#     'name': 'Snake Park',
#     'location': {'lat': 13.003752064318098,
#      'lng': 80.23870160810841,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.003752064318098,
#        'lng': 80.23870160810841}],
#      'distance': 763,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Chennai', 'Tamil Nadu', 'India']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1fd',
#       'name': 'Zoo Exhibit',
#       'pluralName': 'Zoo Exhibits',
#       'shortName': 'Zoo Exhibit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/zoo_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '53522c6d498e830ce0eebb04',
#     'name': 'Knowledge Park',
#     'location': {'address': "knowledge park, opposite to girl's hostel, near IST building,College of engineering guindy,anna university,sardar patel road",
#      'lat': 13.015146046305205,
#      'lng': 80.23576097820109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.015146046305205,
#        'lng': 80.23576097820109}],
#      'distance': 800,
#      'postalCode': '600025',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ["knowledge park, opposite to girl's hostel, near IST building,College of engineering guindy,anna university,sardar patel road",
#       'Chennai 600025',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4d3bbf5e6e0aa1cd44dfdc2c',
#     'name': 'Anna gem science park school',
#     'location': {'lat': 13.016014695167542,
#      'lng': 80.23806810379028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.016014695167542,
#        'lng': 80.23806810379028}],
#      'distance': 992,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Chennai', 'Tamil Nadu', 'India']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '5210b9b011d27053c5e019ea',
#     'name': 'guindy national park',
#     'location': {'lat': 13.012387217908307,
#      'lng': 80.24313958823649,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.012387217908307,
#        'lng': 80.24313958823649}],
#      'distance': 1145,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4e315ec3ae6085c3ad19d5b6',
#     'name': 'P1 Parking',
#     'location': {'address': 'Anna University',
#      'lat': 13.010068335014951,
#      'lng': 80.23288559720645,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.010068335014951,
#        'lng': 80.23288559720645}],
#      'distance': 204,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['Anna University', 'India']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '51108417e4b04bd28a0e7420',
#     'name': 'Anna University Main Parking',
#     'location': {'address': 'Anna University',
#      'crossStreet': 'Guindy',
#      'lat': 13.008230692720522,
#      'lng': 80.23515650277432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.008230692720522,
#        'lng': 80.23515650277432}],
#      'distance': 186,
#      'postalCode': '600025',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University (Guindy)',
#       'Chennai 600025',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '518e0474498e80dabd205b31',
#     'name': 'ceg red building parking lot',
#     'location': {'lat': 13.008893013000488,
#      'lng': 80.23542022705078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.008893013000488,
#        'lng': 80.23542022705078}],
#      'distance': 223,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4d5205bb9ffc236af84029a7',
#     'name': 'Main Gate Parking',
#     'location': {'address': 'Anna University',
#      'lat': 13.00825831502959,
#      'lng': 80.23549318313599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.00825831502959,
#        'lng': 80.23549318313599}],
#      'distance': 222,
#      'postalCode': '600032',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University',
#       'Chennai 600032',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4d54d2f89e508cfa0097f89a',
#     'name': 'P4 Parking.',
#     'location': {'address': 'Anna University',
#      'lat': 13.010487,
#      'lng': 80.235994,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.010487,
#        'lng': 80.235994}],
#      'distance': 367,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4f83d6abe4b06fee7732b79f',
#     'name': 'Mechanical Department Parking',
#     'location': {'address': 'Anna University',
#      'crossStreet': 'Guindy',
#      'lat': 13.009492771177197,
#      'lng': 80.23115923270828,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.009492771177197,
#        'lng': 80.23115923270828}],
#      'distance': 280,
#      'postalCode': '6000025',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University (Guindy)',
#       'Chennai 6000025',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4f0a6ee5e4b05dd3a52fc199',
#     'name': 'AC Tech Campus',
#     'location': {'address': 'Anna University',
#      'crossStreet': 'Sardar Patel Rd.',
#      'lat': 13.007629900921856,
#      'lng': 80.23895210150627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.007629900921856,
#        'lng': 80.23895210150627}],
#      'distance': 602,
#      'postalCode': '600025',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University (Sardar Patel Rd.)',
#       'Chennai 600025',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4d4f76d2e0275481ee3697b6',
#     'name': 'P7 PARKING',
#     'location': {'address': 'CEG',
#      'crossStreet': 'ANNA UNIVERSITY',
#      'lat': 13.007631,
#      'lng': 80.238305,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.007631,
#        'lng': 80.238305}],
#      'distance': 532,
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['CEG (ANNA UNIVERSITY)',
#       'Chennai',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4fe48b87e4b0c48d3d095a1e',
#     'name': 'Hostel parking',
#     'location': {'lat': 13.013000950702482,
#      'lng': 80.24010109436453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.013000950702482,
#        'lng': 80.24010109436453}],
#      'distance': 890,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False},
#    {'id': '4d49009af53c8cfa81ba1247',
#     'name': 'Anna University Side Gate Parking',
#     'location': {'address': 'Anna University (Guindy)',
#      'lat': 13.012293235604366,
#      'lng': 80.24009062641751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.012293235604366,
#        'lng': 80.24009062641751}],
#      'distance': 845,
#      'postalCode': '600032',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'state': 'Tamil Nadu',
#      'country': 'India',
#      'formattedAddress': ['Anna University (Guindy)',
#       'Chennai 600032',
#       'Tamil Nadu',
#       'India']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1590320149',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues_park = results_park['response']['venues']

# tranform venues into a dataframe
dataframe_park = json_normalize(venues_park)
dataframe_park.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                     name  \
# 0  4bc77dc293bdeee1b47037ae   The Park Hotel Chennai
# 1  4b9cbd6cf964a520267936e3    guindy childrens park
# 2  4feedb1be4b01127cbc19930     Guindy National Park
# 3  4f07eb2fe4b0fcefa80570d4   Childrens & snake park
# 4  4c26dfd3c11dc9b672d62924  Children's Park, Guindy
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590320149    False
# 1  [{'id': '4bf58dd8d48988d162941735', 'name': 'O...  v-1590320149    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590320149    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590320149    False
# 4  [{'id': '5bae9231bedf3950379f89d0', 'name': 'S...  v-1590320149    False
#
#   location.address  location.lat  location.lng  \
# 0   601 Anna Salai     13.007489     80.236801
# 1  sardar patel rd     13.005269     80.236630
# 2  Sardar Patel Rd     13.006088     80.238860
# 3              NaN     13.006753     80.238500
# 4              NaN     13.004400     80.238484
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 13.00748881578164...                375
# 1  [{'label': 'display', 'lat': 13.00526859351876...                484
# 2  [{'label': 'display', 'lat': 13.00608772401114...                637
# 3  [{'label': 'display', 'lat': 13.00675322951637...                575
# 4  [{'label': 'display', 'lat': 13.00439991895198...                699
#
#   location.cc location.city location.state location.country  \
# 0          IN       Chennai     Tamil Nadu            India
# 1          IN       Chennai     Tamil Nadu            India
# 2          IN       Chennai     Tamil Nadu            India
# 3          IN           NaN            NaN            India
# 4          IN           NaN            NaN            India
#
#                            location.formattedAddress location.postalCode  \
# 0       [601 Anna Salai, Chennai, Tamil Nadu, India]                 NaN
# 1  [sardar patel rd, Chennai 600032, Tamil Nadu, ...              600032
# 2  [Sardar Patel Rd (Sardar Patel Road), Chennai,...                 NaN
# 3                                            [India]                 NaN
# 4                                            [India]                 NaN
#
#   location.crossStreet
# 0                  NaN
# 1                  NaN
# 2    Sardar Patel Road
# 3                  NaN
# 4                  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_filtered_columns = ['name', 'categories'] + [col for col in dataframe_park.columns if col.startswith('location.')] + ['id']
dataframe_park_filtered = dataframe_park.loc[:, park_filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_park_filtered['categories'] = dataframe_park_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_park_filtered.columns = [column.split('.')[-1] for column in dataframe_park_filtered.columns]

dataframe_park_filtered
# Out:
#                                  name                    categories  \
# 0              The Park Hotel Chennai                         Hotel
# 1               guindy childrens park          Other Great Outdoors
# 2                Guindy National Park                          Park
# 3              Childrens & snake park                          Park
# 4             Children's Park, Guindy       State / Provincial Park
# 5                         Herbal Park                          Park
# 6                          Snake Park                   Zoo Exhibit
# 7                      Knowledge Park     College Academic Building
# 8        Anna gem science park school     College Academic Building
# 9                guindy national park                          Park
# 10                         P1 Parking                       Parking
# 11       Anna University Main Parking                       Parking
# 12       ceg red building parking lot                          Park
# 13                  Main Gate Parking  General College & University
# 14                        P4 Parking.     College Academic Building
# 15      Mechanical Department Parking                       Parking
# 16                     AC Tech Campus  General College & University
# 17                         P7 PARKING                  Noodle House
# 18                     Hostel parking                       Parking
# 19  Anna University Side Gate Parking                       Parking
#
#                                               address        lat        lng  \
# 0                                      601 Anna Salai  13.007489  80.236801
# 1                                     sardar patel rd  13.005269  80.236630
# 2                                     Sardar Patel Rd  13.006088  80.238860
# 3                                                 NaN  13.006753  80.238500
# 4                                                 NaN  13.004400  80.238484
# 5                                         Herbal Park  13.008700  80.239126
# 6                                                 NaN  13.003752  80.238702
# 7   knowledge park, opposite to girl's hostel, nea...  13.015146  80.235761
# 8                                                 NaN  13.016015  80.238068
# 9                                                 NaN  13.012387  80.243140
# 10                                    Anna University  13.010068  80.232886
# 11                                    Anna University  13.008231  80.235157
# 12                                                NaN  13.008893  80.235420
# 13                                    Anna University  13.008258  80.235493
# 14                                    Anna University  13.010487  80.235994
# 15                                    Anna University  13.009493  80.231159
# 16                                    Anna University  13.007630  80.238952
# 17                                                CEG  13.007631  80.238305
# 18                                                NaN  13.013001  80.240101
# 19                           Anna University (Guindy)  13.012293  80.240091
#
#                                        labeledLatLngs  distance  cc     city  \
# 0   [{'label': 'display', 'lat': 13.00748881578164...       375  IN  Chennai
# 1   [{'label': 'display', 'lat': 13.00526859351876...       484  IN  Chennai
# 2   [{'label': 'display', 'lat': 13.00608772401114...       637  IN  Chennai
# 3   [{'label': 'display', 'lat': 13.00675322951637...       575  IN      NaN
# 4   [{'label': 'display', 'lat': 13.00439991895198...       699  IN      NaN
# 5   [{'label': 'display', 'lat': 13.00869964426472...       617  IN  Chennai
# 6   [{'label': 'display', 'lat': 13.00375206431809...       763  IN  Chennai
# 7   [{'label': 'display', 'lat': 13.01514604630520...       800  IN  Chennai
# 8   [{'label': 'display', 'lat': 13.01601469516754...       992  IN  Chennai
# 9   [{'label': 'display', 'lat': 13.01238721790830...      1145  IN      NaN
# 10  [{'label': 'display', 'lat': 13.01006833501495...       204  IN      NaN
# 11  [{'label': 'display', 'lat': 13.00823069272052...       186  IN  Chennai
# 12  [{'label': 'display', 'lat': 13.00889301300048...       223  IN      NaN
# 13  [{'label': 'display', 'lat': 13.00825831502959...       222  IN  Chennai
# 14  [{'label': 'display', 'lat': 13.010487, 'lng':...       367  IN  Chennai
# 15  [{'label': 'display', 'lat': 13.00949277117719...       280  IN  Chennai
# 16  [{'label': 'display', 'lat': 13.00762990092185...       602  IN  Chennai
# 17  [{'label': 'display', 'lat': 13.007631, 'lng':...       532  IN  Chennai
# 18  [{'label': 'display', 'lat': 13.01300095070248...       890  IN      NaN
# 19  [{'label': 'display', 'lat': 13.01229323560436...       845  IN  Chennai
#
#          state country                                   formattedAddress  \
# 0   Tamil Nadu   India       [601 Anna Salai, Chennai, Tamil Nadu, India]
# 1   Tamil Nadu   India  [sardar patel rd, Chennai 600032, Tamil Nadu, ...
# 2   Tamil Nadu   India  [Sardar Patel Rd (Sardar Patel Road), Chennai,...
# 3          NaN   India                                            [India]
# 4          NaN   India                                            [India]
# 5   Tamil Nadu   India  [Herbal Park (Madras University), Chennai, Tam...
# 6   Tamil Nadu   India                       [Chennai, Tamil Nadu, India]
# 7   Tamil Nadu   India  [knowledge park, opposite to girl's hostel, ne...
# 8   Tamil Nadu   India                       [Chennai, Tamil Nadu, India]
# 9          NaN   India                                            [India]
# 10         NaN   India                           [Anna University, India]
# 11  Tamil Nadu   India  [Anna University (Guindy), Chennai 600025, Tam...
# 12         NaN   India                                            [India]
# 13  Tamil Nadu   India  [Anna University, Chennai 600032, Tamil Nadu, ...
# 14  Tamil Nadu   India      [Anna University, Chennai, Tamil Nadu, India]
# 15  Tamil Nadu   India  [Anna University (Guindy), Chennai 6000025, Ta...
# 16  Tamil Nadu   India  [Anna University (Sardar Patel Rd.), Chennai 6...
# 17  Tamil Nadu   India  [CEG (ANNA UNIVERSITY), Chennai, Tamil Nadu, I...
# 18         NaN   India                                            [India]
# 19  Tamil Nadu   India  [Anna University (Guindy), Chennai 600032, Tam...
#
#    postalCode        crossStreet                        id
# 0         NaN                NaN  4bc77dc293bdeee1b47037ae
# 1      600032                NaN  4b9cbd6cf964a520267936e3
# 2         NaN  Sardar Patel Road  4feedb1be4b01127cbc19930
# 3         NaN                NaN  4f07eb2fe4b0fcefa80570d4
# 4         NaN                NaN  4c26dfd3c11dc9b672d62924
# 5         NaN  Madras University  4f3373b7e4b00f87aa73f865
# 6         NaN                NaN  4c550f46f5f3d13a152e20fb
# 7      600025                NaN  53522c6d498e830ce0eebb04
# 8         NaN                NaN  4d3bbf5e6e0aa1cd44dfdc2c
# 9         NaN                NaN  5210b9b011d27053c5e019ea
# 10        NaN                NaN  4e315ec3ae6085c3ad19d5b6
# 11     600025             Guindy  51108417e4b04bd28a0e7420
# 12        NaN                NaN  518e0474498e80dabd205b31
# 13     600032                NaN  4d5205bb9ffc236af84029a7
# 14        NaN                NaN  4d54d2f89e508cfa0097f89a
# 15    6000025             Guindy  4f83d6abe4b06fee7732b79f
# 16     600025   Sardar Patel Rd.  4f0a6ee5e4b05dd3a52fc199
# 17        NaN    ANNA UNIVERSITY  4d4f76d2e0275481ee3697b6
# 18        NaN                NaN  4fe48b87e4b0c48d3d095a1e
# 19     600032                NaN  4d49009af53c8cfa81ba1247

# %%
dataframe_park_filtered.name
# Out:
# 0                The Park Hotel Chennai
# 1                 guindy childrens park
# 2                  Guindy National Park
# 3                Childrens & snake park
# 4               Children's Park, Guindy
# 5                           Herbal Park
# 6                            Snake Park
# 7                        Knowledge Park
# 8          Anna gem science park school
# 9                  guindy national park
# 10                           P1 Parking
# 11         Anna University Main Parking
# 12         ceg red building parking lot
# 13                    Main Gate Parking
# 14                          P4 Parking.
# 15        Mechanical Department Parking
# 16                       AC Tech Campus
# 17                           P7 PARKING
# 18                       Hostel parking
# 19    Anna University Side Gate Parking
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Anna University',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_park_filtered.lat, dataframe_park_filtered.lng, dataframe_park_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Explore a location

# %% [markdown]
# #### So, you just finished your tour at AU, and are just curious about the popular spots around. In order to explore the area, let's start by getting the latitude and longitude values of AU.

# %%
latitude = 13.0083174
longitude = 80.2334438

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=ALFKCZOUD5L4R1BBEVEVJT3G2FWIPRHJX0AMMJT2DSI3GPPS&client_secret=VKFBW4PSYNDTRLXMSLI3I44L4JF3ETZGAWET3I0FLTG1KOTF&ll=13.0083174,80.2334438&v=20180604&radius=1000&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around AU.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 6 around AU.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4cac7ec45a1e95212ca08ece',
#   'name': 'Main Canteen',
#   'location': {'address': 'Anna University',
#    'lat': 13.0107864888924,
#    'lng': 80.2364525799455,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 13.0107864888924,
#      'lng': 80.2364525799455}],
#    'distance': 426,
#    'postalCode': '600032',
#    'cc': 'IN',
#    'city': 'Chennai',
#    'state': 'Tamil Nadu',
#    'country': 'India',
#    'formattedAddress': ['Anna University',
#     'Chennai 600032',
#     'Tamil Nadu',
#     'India']},
#   'categories': [{'id': '4bf58dd8d48988d1a1941735',
#     'name': 'College Cafeteria',
#     'pluralName': 'College Cafeterias',
#     'shortName': 'Cafeteria',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4cac7ec45a1e95212ca08ece-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                         name               categories  \
# 0               Main Canteen        College Cafeteria
# 1            Gurunath Stores        College Cafeteria
# 2  Lemon Tree Hotel, Chennai                    Hotel
# 3            Gandhi Mandapam                     Park
# 4    Children's Park, Guindy  State / Provincial Park
# 5                Juice World                Juice Bar
#
#                                              address        lat        lng  \
# 0                                    Anna University  13.010786  80.236453
# 1                                    Anna University  13.014251  80.236272
# 2  72, Sardar Patel Road, Guindy Vinayagar Koil S...  13.010897  80.224622
# 3                                              Adyar  13.007503  80.237956
# 4                                                NaN  13.004400  80.238484
# 5                                   Sri Nagar Colony  13.012168  80.227189
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 13.0107864888924,...       426     600032  IN
# 1  [{'label': 'display', 'lat': 13.01425140697678...       728     600032  IN
# 2  [{'label': 'display', 'lat': 13.01089663387729...       998     600015  IN
# 3  [{'label': 'display', 'lat': 13.00750342876191...       497        NaN  IN
# 4  [{'label': 'display', 'lat': 13.00439991895198...       699        NaN  IN
# 5  [{'label': 'display', 'lat': 13.01216789647054...       802     600015  IN
#
#       city       state country  \
# 0  Chennai  Tamil Nadu   India
# 1  Chennai  Tamil Nadu   India
# 2  Chennai  Tamil Nadu   India
# 3  Chennai  Tamil Nadu   India
# 4      NaN         NaN   India
# 5  Chennai  Tamil Nadu   India
#
#                                     formattedAddress        crossStreet  \
# 0  [Anna University, Chennai 600032, Tamil Nadu, ...                NaN
# 1  [Anna University, Chennai 600032, Tamil Nadu, ...                NaN
# 2  [72, Sardar Patel Road, Guindy Vinayagar Koil ...                NaN
# 3  [Adyar (Sardar Patel Road), Chennai, Tamil Nad...  Sardar Patel Road
# 4                                            [India]                NaN
# 5  [Sri Nagar Colony (Saidapet), Chennai 600015, ...           Saidapet
#
#                          id
# 0  4cac7ec45a1e95212ca08ece
# 1  4d4ced8981955481a662d293
# 2  4c388ff11e06d13acae5773e
# 3  4cb87a48035d236ac352cd4e
# 4  4c26dfd3c11dc9b672d62924
# 5  4fcf0d96e4b065df8f1c82cf

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=17,tiles="OpenStreetMap") # generate map centred around AU


# add AU as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Anna University',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)

tooltip = 'Click me!'
# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# limited zoom - lz
#
# tiles="Stamen Toner"
# tiles="Stamen Terrain" --> lz
# tiles="OpenStreetMap"
# tiles="Stamen Watercolor"
# tiles="cartodbpositron"
# tiles="cartodbdark_matter"
# tiles="Mapbox Bright" --> Doesn't work
